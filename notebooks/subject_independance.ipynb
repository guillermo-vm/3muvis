# %% [markdown]
# # Subject independance check

# %% [markdown]
# libraries

# %%
import pandas as pd

# %% [markdown]
# datasets

# %%
htad = pd.read_csv("../datasets/HTAD.csv")
har70 = pd.read_csv("../datasets/HAR70+.csv")
mhad = pd.read_csv("../datasets/berkeley.csv")

# %%
htad.head()
# Out:
#   userid     label    v1_mfcc1  v1_mfcc2  v1_mfcc3   v1_mfcc4  v1_mfcc5  \
# 0  user1  watch_tv  120.078886  3.025171  0.390508  -1.777848 -9.216060
# 1  user1  watch_tv  130.243139  2.552278 -6.457879  -7.440159 -3.070106
# 2  user1  watch_tv  122.259209  1.970267 -8.980575 -10.222030 -3.564994
# 3  user1  watch_tv  122.609566  3.188740 -7.049397 -10.569875 -0.220824
# 4  user1  watch_tv  121.393023  1.338798 -8.706183  -8.654997 -4.935310
#
#    v1_mfcc6  v1_mfcc7  v1_mfcc8  ...   v2_maxX   v2_maxY   v2_maxZ  v2_corXY  \
# 0 -6.567632 -9.918761 -9.145534  ...  0.097412  1.088135  0.227051  0.900163
# 1 -3.475476 -5.718819 -2.878174  ...  0.703613  1.424805  0.818115 -0.210431
# 2 -2.496906 -5.584900 -6.730588  ...  0.312500  0.972656 -0.070312 -0.018862
# 3 -0.649459 -4.975825 -6.856288  ...  0.349854  1.020020 -0.053223  0.492439
# 4 -3.401656 -5.031361 -7.957924  ...  0.322266  0.955078 -0.076904 -0.226296
#
# ...

# %% [markdown]
# ## HTAD check

# %%
htad.groupby(["userid", "label"])["label"].value_counts()
# Out:
# userid  label
# user1   brush_teeth          59
#         eat_chips           153
#         mop_floor            56
#         sweep                47
#         type_on_keyboard     49
#         wash_hands           36
#         watch_tv             66
# user2   brush_teeth          57
#         eat_chips            65
#         mop_floor            63
#         sweep                68
#         type_on_keyboard     63
#         wash_hands           79
#         watch_tv             71
# user3   brush_teeth          64
#         eat_chips            64
#         mop_floor            62
#         sweep                63
#         type_on_keyboard     67
#         wash_hands           65
#         watch_tv             69
# Name: count, dtype: int64

# %%
htad["userid"].value_counts()
# Out:
# userid
# user1    466
# user2    466
# user3    454
# Name: count, dtype: int64

# %% [markdown]
# ## HAR70+ Check

# %%
har70.head()
# Out:
#    userid    label  v1_meanX  v1_meanY  v1_meanZ    v1_sdX    v1_sdY  \
# 0     501  walking -0.982145 -0.021472 -0.218573  0.063841  0.110760
# 1     501  walking -1.003945 -0.055020 -0.150732  0.114290  0.075176
# 2     501  walking -0.994657 -0.041391 -0.161117  0.067852  0.107584
# 3     501  walking -1.005066 -0.086511 -0.170156  0.105186  0.082683
# 4     501  walking -0.999507 -0.084847 -0.207869  0.091950  0.081913
#
#      v1_sdZ   v1_maxX   v1_maxY  ...  v2_minX2  v2_minY2  v2_minZ2  v2_corXY2  \
# 0  0.061010 -0.836035  0.180957  ... -1.147290 -0.435913 -0.679614   0.249326
# 1  0.083377 -0.817676  0.066455  ... -1.346973 -0.321582 -0.670654   0.542167
# 2  0.137541 -0.888013  0.177832  ... -1.148071 -0.241113 -0.689697   0.012539
# 3  0.085037 -0.859424  0.073731  ... -1.314575 -0.278320 -0.684375   0.127624
# 4  0.078310 -0.856299  0.057519  ... -1.287256 -0.268579 -0.648730   0.185175
#
#    v2_corXZ2  v2_corYZ2  v2_meanMagnitude2  v2_sdMagnitude2     v2_auc2  \
# ...

# %%
len(har70["userid"].unique())
# Out:
# 18

# %%
har70.groupby(["userid", "label"])["label"]

# %% [markdown]
# # MHAD check

# %%
mhad.head()
# Out:
#   class  v1_Mic01mfcc1  v1_Mic01mfcc2  v1_Mic01mfcc3  v1_Mic01mfcc4  \
# 0   a01       0.079710       0.769658       0.830407       0.356513
# 1   a01       0.159042       0.703198       0.654148       0.532655
# 2   a01       0.201678       0.668549       0.560725       0.448048
# 3   a01       0.126777       0.784201       0.730486       0.336550
# 4   a01       0.097669       0.758022       0.820271       0.322435
#
#    v1_Mic01mfcc5  v1_Mic01mfcc6  v1_Mic01mfcc7  v1_Mic01mfcc8  v1_Mic01mfcc9  \
# 0       0.782229       0.190463       0.861372       0.567263       0.603267
# 1       0.715287       0.218365       0.857341       0.585356       0.754775
# 2       0.766439       0.251589       0.716053       0.686217       0.698206
# 3       0.733965       0.157373       0.981363       0.620040       0.561619
# 4       0.751854       0.235266       0.830231       0.591475       0.505623
#
#    ...  v3_minDist21  v3_minDist22  v3_minDist23  v3_minDist24  v3_minDist25  \
# ...
